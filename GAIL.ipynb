# %%
import numpy as np
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.ppo import MlpPolicy
import torch

from imitation.algorithms.adversarial.gail import GAIL
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.policies.serialize import load_policy
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from imitation.util.util import make_vec_env

SEED = 42

# %%
env = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=np.random.default_rng(SEED),
    n_envs=8,
    post_wrappers=[lambda env, _: RolloutInfoWrapper(env)],  # to compute rollouts
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals-CartPole-v0",
    venv=env,
)

# %%
rollouts = rollout.rollout(
    expert,
    env,
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=np.random.default_rng(SEED),
)

# %%
learner = PPO(
    env=env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0004,
    gamma=0.95,
    n_epochs=5,
    seed=SEED,
)
reward_net = BasicRewardNet(
    observation_space=env.observation_space,
    action_space=env.action_space,
    normalize_input_layer=RunningNorm,
)
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=env,
    gen_algo=learner,
    reward_net=reward_net,
)

# %%
# evaluate the learner before training
env.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True,
)

# %%
# train the learner and evaluate again
gail_trainer.train(800000)  # Train for 800_000 steps to match expert.
env.seed(SEED)
# Out:
# round:   0%|          | 0/48 [00:00<?, ?it/s]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 35.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 270         |
# |    gen/time/fps                    | 5854        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 32768       |
# |    gen/train/approx_kl             | 0.006985949 |
# |    gen/train/clip_fraction         | 0.0338      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.687      |
# |    gen/train/explained_variance    | 0.0555256   |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0315      |
# |    gen/train/n_updates             | 5           |
# |    gen/train/policy_gradient_loss  | -0.00158    |
# |    gen/train/value_loss            | 4.7         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.5         |
# |    disc/disc_acc_expert             | 0           |
# |    disc/disc_acc_gen                | 1           |
# |    disc/disc_entropy                | 0.69        |
# |    disc/disc_loss                   | 0.675       |
# |    disc/disc_proportion_expert_pred | 0           |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 2           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 35.3        |
# |    gen/rollout/ep_rew_wrapped_mean  | 270         |
# |    gen/time/fps                     | 5.85e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 3.28e+04    |
# |    gen/train/approx_kl              | 0.008539271 |
# |    gen/train/clip_fraction          | 0.0651      |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.677      |
# |    gen/train/explained_variance     | 0.7282779   |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | 0.0787      |
# |    gen/train/n_updates              | 10          |
# |    gen/train/policy_gradient_loss   | -0.00236    |
# |    gen/train/value_loss             | 0.26        |
# -----------------------------------------------------
# round:   2%|▏         | 1/48 [00:05<04:40,  5.97s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 33.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 284         |
# |    gen/time/fps                    | 5796        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 49152       |
# |    gen/train/approx_kl             | 0.008539271 |
# |    gen/train/clip_fraction         | 0.0651      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.677      |
# |    gen/train/explained_variance    | 0.7282779   |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0787      |
# |    gen/train/n_updates             | 10          |
# |    gen/train/policy_gradient_loss  | -0.00236    |
# |    gen/train/value_loss            | 0.26        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.667    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.5         |
# |    disc/disc_acc_expert             | 0           |
# |    disc/disc_acc_gen                | 1           |
# |    disc/disc_entropy                | 0.688       |
# |    disc/disc_loss                   | 0.669       |
# |    disc/disc_proportion_expert_pred | 0           |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 3           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 33.3        |
# |    gen/rollout/ep_rew_wrapped_mean  | 284         |
# |    gen/time/fps                     | 5.8e+03     |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 4.92e+04    |
# |    gen/train/approx_kl              | 0.010250306 |
# |    gen/train/clip_fraction          | 0.0683      |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.678      |
# |    gen/train/explained_variance     | 0.8897878   |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | 0.0143      |
# |    gen/train/n_updates              | 15          |
# |    gen/train/policy_gradient_loss   | -0.00383    |
# |    gen/train/value_loss             | 0.0453      |
# -----------------------------------------------------
# round:   4%|▍         | 2/48 [00:12<04:38,  6.05s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 37.2        |
# |    gen/rollout/ep_rew_wrapped_mean | 278         |
# |    gen/time/fps                    | 5743        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 65536       |
# |    gen/train/approx_kl             | 0.010250306 |
# |    gen/train/clip_fraction         | 0.0683      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.678      |
# |    gen/train/explained_variance    | 0.8897878   |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0143      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -0.00383    |
# |    gen/train/value_loss            | 0.0453      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.658    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.66     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.656    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.655    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.687    |
# |    disc/disc_loss                   | 0.654    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.498    |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 0.995    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0.00244  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.49     |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 0.979    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.65     |
# |    disc/disc_proportion_expert_pred | 0.0103   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.498       |
# |    disc/disc_acc_expert             | 0           |
# |    disc/disc_acc_gen                | 0.997       |
# |    disc/disc_entropy                | 0.687       |
# |    disc/disc_loss                   | 0.656       |
# |    disc/disc_proportion_expert_pred | 0.00159     |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 4           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 37.2        |
# |    gen/rollout/ep_rew_wrapped_mean  | 278         |
# |    gen/time/fps                     | 5.74e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 6.55e+04    |
# |    gen/train/approx_kl              | 0.012314845 |
# |    gen/train/clip_fraction          | 0.137       |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.664      |
# |    gen/train/explained_variance     | 0.9172405   |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | -0.00381    |
# |    gen/train/n_updates              | 20          |
# |    gen/train/policy_gradient_loss   | -0.0127     |
# |    gen/train/value_loss             | 0.0192      |
# -----------------------------------------------------
# round:   6%|▋         | 3/48 [00:18<04:30,  6.02s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 40.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 278         |
# |    gen/time/fps                    | 5770        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 81920       |
# |    gen/train/approx_kl             | 0.012314845 |
# |    gen/train/clip_fraction         | 0.137       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.664      |
# |    gen/train/explained_variance    | 0.9172405   |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.00381    |
# |    gen/train/n_updates             | 20          |
# |    gen/train/policy_gradient_loss  | -0.0127     |
# |    gen/train/value_loss            | 0.0192      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.481    |
# |    disc/disc_acc_expert             | 0.00391  |
# |    disc/disc_acc_gen                | 0.958    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.0229   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.491    |
# |    disc/disc_acc_expert             | 0.0322   |
# |    disc/disc_acc_gen                | 0.949    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.0415   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.525    |
# |    disc/disc_acc_expert             | 0.113    |
# |    disc/disc_acc_gen                | 0.937    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.643    |
# |    disc/disc_proportion_expert_pred | 0.0884   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.604    |
# |    disc/disc_acc_expert             | 0.284    |
# |    disc/disc_acc_gen                | 0.923    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.181    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.667    |
# |    disc/disc_acc_expert             | 0.416    |
# |    disc/disc_acc_gen                | 0.919    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.639    |
# |    disc/disc_proportion_expert_pred | 0.249    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.705    |
# |    disc/disc_acc_expert             | 0.496    |
# |    disc/disc_acc_gen                | 0.914    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.636    |
# |    disc/disc_proportion_expert_pred | 0.291    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.7      |
# |    disc/disc_acc_expert             | 0.497    |
# |    disc/disc_acc_gen                | 0.902    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.297    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.696    |
# |    disc/disc_acc_expert             | 0.506    |
# |    disc/disc_acc_gen                | 0.887    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.631    |
# |    disc/disc_proportion_expert_pred | 0.31     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.609       |
# |    disc/disc_acc_expert             | 0.294       |
# |    disc/disc_acc_gen                | 0.924       |
# |    disc/disc_entropy                | 0.685       |
# |    disc/disc_loss                   | 0.639       |
# |    disc/disc_proportion_expert_pred | 0.185       |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 5           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 40.9        |
# |    gen/rollout/ep_rew_wrapped_mean  | 278         |
# |    gen/time/fps                     | 5.77e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 8.19e+04    |
# |    gen/train/approx_kl              | 0.012895412 |
# |    gen/train/clip_fraction          | 0.147       |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.649      |
# |    gen/train/explained_variance     | 0.90165746  |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | 0.0011      |
# |    gen/train/n_updates              | 25          |
# |    gen/train/policy_gradient_loss   | -0.0139     |
# |    gen/train/value_loss             | 0.0171      |
# -----------------------------------------------------
# round:   8%|▊         | 4/48 [00:23<04:23,  5.98s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 44.2        |
# |    gen/rollout/ep_rew_wrapped_mean | 276         |
# |    gen/time/fps                    | 6226        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.012895412 |
# |    gen/train/clip_fraction         | 0.147       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.649      |
# |    gen/train/explained_variance    | 0.90165746  |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0011      |
# |    gen/train/n_updates             | 25          |
# |    gen/train/policy_gradient_loss  | -0.0139     |
# |    gen/train/value_loss            | 0.0171      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.715    |
# |    disc/disc_acc_expert             | 0.511    |
# |    disc/disc_acc_gen                | 0.919    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.63     |
# |    disc/disc_proportion_expert_pred | 0.296    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.72     |
# |    disc/disc_acc_expert             | 0.526    |
# |    disc/disc_acc_gen                | 0.913    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.63     |
# |    disc/disc_proportion_expert_pred | 0.307    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.697    |
# |    disc/disc_acc_expert             | 0.497    |
# |    disc/disc_acc_gen                | 0.896    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.3      |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.7      |
# |    disc/disc_acc_expert             | 0.487    |
# |    disc/disc_acc_gen                | 0.913    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.628    |
# |    disc/disc_proportion_expert_pred | 0.287    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.711    |
# |    disc/disc_acc_expert             | 0.514    |
# |    disc/disc_acc_gen                | 0.908    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.303    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.709    |
# |    disc/disc_acc_expert             | 0.516    |
# |    disc/disc_acc_gen                | 0.902    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.624    |
# |    disc/disc_proportion_expert_pred | 0.307    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.693    |
# |    disc/disc_acc_expert             | 0.488    |
# |    disc/disc_acc_gen                | 0.898    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.295    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.731    |
# |    disc/disc_acc_expert             | 0.561    |
# |    disc/disc_acc_gen                | 0.901    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.618    |
# |    disc/disc_proportion_expert_pred | 0.33     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.709       |
# |    disc/disc_acc_expert             | 0.512       |
# |    disc/disc_acc_gen                | 0.906       |
# |    disc/disc_entropy                | 0.683       |
# |    disc/disc_loss                   | 0.625       |
# |    disc/disc_proportion_expert_pred | 0.303       |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 6           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 44.2        |
# |    gen/rollout/ep_rew_wrapped_mean  | 276         |
# |    gen/time/fps                     | 6.23e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 9.83e+04    |
# |    gen/train/approx_kl              | 0.011982788 |
# |    gen/train/clip_fraction          | 0.134       |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.622      |
# |    gen/train/explained_variance     | 0.92562973  |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | 0.013       |
# |    gen/train/n_updates              | 30          |
# |    gen/train/policy_gradient_loss   | -0.00982    |
# |    gen/train/value_loss             | 0.0153      |
# -----------------------------------------------------
# round:  10%|█         | 5/48 [00:29<04:13,  5.89s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 46          |
# |    gen/rollout/ep_rew_wrapped_mean | 282         |
# |    gen/time/fps                    | 6188        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 114688      |
# |    gen/train/approx_kl             | 0.011982788 |
# |    gen/train/clip_fraction         | 0.134       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.622      |
# |    gen/train/explained_variance    | 0.92562973  |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.013       |
# |    gen/train/n_updates             | 30          |
# |    gen/train/policy_gradient_loss  | -0.00982    |
# |    gen/train/value_loss            | 0.0153      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.824    |
# |    disc/disc_acc_expert             | 0.748    |
# |    disc/disc_acc_gen                | 0.9      |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.619    |
# |    disc/disc_proportion_expert_pred | 0.424    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.917    |
# |    disc/disc_acc_expert             | 0.949    |
# |    disc/disc_acc_gen                | 0.885    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.619    |
# |    disc/disc_proportion_expert_pred | 0.532    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.93     |
# |    disc/disc_acc_expert             | 0.994    |
# |    disc/disc_acc_gen                | 0.865    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.616    |
# |    disc/disc_proportion_expert_pred | 0.564    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.931    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.861    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.614    |
# |    disc/disc_proportion_expert_pred | 0.569    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.935    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.87     |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.611    |
# |    disc/disc_proportion_expert_pred | 0.565    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.928    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.856    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.61     |
# |    disc/disc_proportion_expert_pred | 0.572    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.926    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.853    |
# |    disc/disc_entropy                | 0.678    |
# |    disc/disc_loss                   | 0.605    |
# |    disc/disc_proportion_expert_pred | 0.574    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.919    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.838    |
# |    disc/disc_entropy                | 0.676    |
# |    disc/disc_loss                   | 0.6      |
# |    disc/disc_proportion_expert_pred | 0.581    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.914       |
# |    disc/disc_acc_expert             | 0.961       |
# |    disc/disc_acc_gen                | 0.866       |
# |    disc/disc_entropy                | 0.68        |
# |    disc/disc_loss                   | 0.612       |
# |    disc/disc_proportion_expert_pred | 0.548       |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 7           |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 46          |
# |    gen/rollout/ep_rew_wrapped_mean  | 282         |
# |    gen/time/fps                     | 6.19e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 1.15e+05    |
# |    gen/train/approx_kl              | 0.010335151 |
# |    gen/train/clip_fraction          | 0.104       |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.609      |
# |    gen/train/explained_variance     | 0.94261414  |
# |    gen/train/learning_rate          | 0.0004      |
# ...
# |    gen/rollout/ep_rew_wrapped_mean | 414         |
# |    gen/time/fps                    | 6280        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 2           |
# |    gen/time/total_timesteps        | 786432      |
# |    gen/train/approx_kl             | 0.009355076 |
# |    gen/train/clip_fraction         | 0.106       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.295      |
# |    gen/train/explained_variance    | 0.9822101   |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.00842     |
# |    gen/train/n_updates             | 235         |
# |    gen/train/policy_gradient_loss  | -0.00484    |
# |    gen/train/value_loss            | 0.0067      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.354    |
# |    disc/disc_acc_expert             | 0.524    |
# |    disc/disc_acc_gen                | 0.185    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.751    |
# |    disc/disc_proportion_expert_pred | 0.67     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.361    |
# |    disc/disc_acc_expert             | 0.514    |
# |    disc/disc_acc_gen                | 0.208    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.745    |
# |    disc/disc_proportion_expert_pred | 0.653    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.343    |
# |    disc/disc_acc_expert             | 0.488    |
# |    disc/disc_acc_gen                | 0.197    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.744    |
# |    disc/disc_proportion_expert_pred | 0.646    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.341    |
# |    disc/disc_acc_expert             | 0.505    |
# |    disc/disc_acc_gen                | 0.177    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.747    |
# |    disc/disc_proportion_expert_pred | 0.664    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.36     |
# |    disc/disc_acc_expert             | 0.524    |
# |    disc/disc_acc_gen                | 0.196    |
# |    disc/disc_entropy                | 0.682    |
# |    disc/disc_loss                   | 0.743    |
# |    disc/disc_proportion_expert_pred | 0.664    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.361    |
# |    disc/disc_acc_expert             | 0.501    |
# |    disc/disc_acc_gen                | 0.221    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.735    |
# |    disc/disc_proportion_expert_pred | 0.64     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.353    |
# |    disc/disc_acc_expert             | 0.491    |
# |    disc/disc_acc_gen                | 0.215    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.74     |
# |    disc/disc_proportion_expert_pred | 0.638    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.366    |
# |    disc/disc_acc_expert             | 0.524    |
# |    disc/disc_acc_gen                | 0.207    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.736    |
# |    disc/disc_proportion_expert_pred | 0.659    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 48       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# ------------------------------------------------------
# | mean/                               |              |
# |    disc/disc_acc                    | 0.355        |
# |    disc/disc_acc_expert             | 0.509        |
# |    disc/disc_acc_gen                | 0.201        |
# |    disc/disc_entropy                | 0.682        |
# |    disc/disc_loss                   | 0.742        |
# |    disc/disc_proportion_expert_pred | 0.654        |
# |    disc/disc_proportion_expert_true | 0.5          |
# |    disc/global_step                 | 48           |
# |    disc/n_expert                    | 1.02e+03     |
# |    disc/n_generated                 | 1.02e+03     |
# |    gen/rollout/ep_len_mean          | 500          |
# |    gen/rollout/ep_rew_mean          | 500          |
# |    gen/rollout/ep_rew_wrapped_mean  | 414          |
# |    gen/time/fps                     | 6.28e+03     |
# |    gen/time/iterations              | 1            |
# |    gen/time/time_elapsed            | 2            |
# |    gen/time/total_timesteps         | 7.86e+05     |
# |    gen/train/approx_kl              | 0.0058190124 |
# |    gen/train/clip_fraction          | 0.0626       |
# |    gen/train/clip_range             | 0.2          |
# |    gen/train/entropy_loss           | -0.278       |
# |    gen/train/explained_variance     | 0.9946737    |
# |    gen/train/learning_rate          | 0.0004       |
# |    gen/train/loss                   | -0.00358     |
# |    gen/train/n_updates              | 240          |
# |    gen/train/policy_gradient_loss   | -0.00311     |
# |    gen/train/value_loss             | 0.0101       |
# ------------------------------------------------------
# round:  98%|█████████▊| 47/48 [04:24<00:05,  5.59s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 500          |
# |    gen/rollout/ep_rew_wrapped_mean | 408          |
# |    gen/time/fps                    | 6258         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 2            |
# |    gen/time/total_timesteps        | 802816       |
# |    gen/train/approx_kl             | 0.0058190124 |
# |    gen/train/clip_fraction         | 0.0626       |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -0.278       |
# |    gen/train/explained_variance    | 0.9946737    |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | -0.00358     |
# |    gen/train/n_updates             | 240          |
# |    gen/train/policy_gradient_loss  | -0.00311     |
# |    gen/train/value_loss            | 0.0101       |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.376    |
# |    disc/disc_acc_expert             | 0.509    |
# |    disc/disc_acc_gen                | 0.243    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.737    |
# |    disc/disc_proportion_expert_pred | 0.633    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.351    |
# |    disc/disc_acc_expert             | 0.497    |
# |    disc/disc_acc_gen                | 0.204    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.744    |
# |    disc/disc_proportion_expert_pred | 0.646    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.35     |
# |    disc/disc_acc_expert             | 0.488    |
# |    disc/disc_acc_gen                | 0.211    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.739    |
# |    disc/disc_proportion_expert_pred | 0.639    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.34     |
# |    disc/disc_acc_expert             | 0.476    |
# |    disc/disc_acc_gen                | 0.205    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.743    |
# |    disc/disc_proportion_expert_pred | 0.635    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.354    |
# |    disc/disc_acc_expert             | 0.478    |
# |    disc/disc_acc_gen                | 0.23     |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.734    |
# |    disc/disc_proportion_expert_pred | 0.624    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.32     |
# |    disc/disc_acc_expert             | 0.432    |
# |    disc/disc_acc_gen                | 0.208    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.739    |
# |    disc/disc_proportion_expert_pred | 0.612    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.308    |
# |    disc/disc_acc_expert             | 0.43     |
# |    disc/disc_acc_gen                | 0.187    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.741    |
# |    disc/disc_proportion_expert_pred | 0.622    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.327    |
# |    disc/disc_acc_expert             | 0.404    |
# |    disc/disc_acc_gen                | 0.249    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.733    |
# |    disc/disc_proportion_expert_pred | 0.578    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 49       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# -----------------------------------------------------
# | mean/                               |             |
# |    disc/disc_acc                    | 0.341       |
# |    disc/disc_acc_expert             | 0.464       |
# |    disc/disc_acc_gen                | 0.217       |
# |    disc/disc_entropy                | 0.685       |
# |    disc/disc_loss                   | 0.739       |
# |    disc/disc_proportion_expert_pred | 0.623       |
# |    disc/disc_proportion_expert_true | 0.5         |
# |    disc/global_step                 | 49          |
# |    disc/n_expert                    | 1.02e+03    |
# |    disc/n_generated                 | 1.02e+03    |
# |    gen/rollout/ep_len_mean          | 500         |
# |    gen/rollout/ep_rew_mean          | 500         |
# |    gen/rollout/ep_rew_wrapped_mean  | 408         |
# |    gen/time/fps                     | 6.26e+03    |
# |    gen/time/iterations              | 1           |
# |    gen/time/time_elapsed            | 2           |
# |    gen/time/total_timesteps         | 8.03e+05    |
# |    gen/train/approx_kl              | 0.004754376 |
# |    gen/train/clip_fraction          | 0.0417      |
# |    gen/train/clip_range             | 0.2         |
# |    gen/train/entropy_loss           | -0.257      |
# |    gen/train/explained_variance     | 0.990405    |
# |    gen/train/learning_rate          | 0.0004      |
# |    gen/train/loss                   | -0.0132     |
# |    gen/train/n_updates              | 245         |
# |    gen/train/policy_gradient_loss   | -0.00113    |
# |    gen/train/value_loss             | 0.00988     |
# -----------------------------------------------------
# round: 100%|██████████| 48/48 [04:30<00:00,  5.63s/it]
# [42, 43, 44, 45, 46, 47, 48, 49]

# %%
learner_rewards_after_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True,
)

# %%
print("mean reward after training:", np.mean(learner_rewards_after_training))
print("mean reward before training:", np.mean(learner_rewards_before_training))
# Out:
# mean reward after training: 500.0
# mean reward before training: 102.6

# %%
learner.save("models/gail_cartpole_learner")

# %%
expert = PPO.load("models/gail_cartpole_learner", env=env)

# %%
env  = gym.make("seals:seals/CartPole-v0", render_mode='human')
obs, _ = env.reset()
env.render()
done = False
truncated = False   
g_reward = 0
for _ in range(10):
    while not done and not truncated:
        # Predict action
        action, _states = expert.predict(obs, deterministic=True)

        # Step in environment
        obs, reward, done, truncated, info = env.step(action)
        g_reward += reward
        # Optional: render is handled automatically with render_mode="human"
        
        print(f"Reward: {g_reward}")
env.close()
# Out:
# Reward: 1.0
# Reward: 2.0
# Reward: 3.0
# Reward: 4.0
# Reward: 5.0
# Reward: 6.0
# Reward: 7.0
# Reward: 8.0
# Reward: 9.0
# Reward: 10.0
# Reward: 11.0
# Reward: 12.0
# Reward: 13.0
# Reward: 14.0
# Reward: 15.0
# Reward: 16.0
# Reward: 17.0
# Reward: 18.0
# Reward: 19.0
# Reward: 20.0
# Reward: 21.0
# Reward: 22.0
# Reward: 23.0
# Reward: 24.0
# Reward: 25.0
# Reward: 26.0
# Reward: 27.0
# Reward: 28.0
# Reward: 29.0
# Reward: 30.0
# Reward: 31.0
# Reward: 32.0
# Reward: 33.0
# Reward: 34.0
# Reward: 35.0
